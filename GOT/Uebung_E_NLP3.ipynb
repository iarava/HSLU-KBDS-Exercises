# %% [markdown]
# # Thrones2Vec

# %% [markdown]
# © Yuriy Guts, 2016

# %% [markdown]
# Using only the raw text of [A Song of Ice and Fire](https://en.wikipedia.org/wiki/A_Song_of_Ice_and_Fire), we'll derive and explore the semantic properties of its words.

# %% [markdown]
# ## Imports

# %%
from __future__ import absolute_import, division, print_function

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# **Download NLTK tokenizer models (only the first time)**

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lucar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lucar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Prepare Corpus

# %% [markdown]
# **Load books from files**

# %%
book_filenames = sorted(glob.glob("data/*.txt"))

# %%
print("Found books:")
book_filenames
# Out:
# Found books:
# ['data\\got1.txt',
#  'data\\got2.txt',
#  'data\\got3.txt',
#  'data\\got4.txt',
#  'data\\got5.txt']

# %% [markdown]
# **Combine the books into one string**

# %%
corpus_raw = u""
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'data\got1.txt'...
# Corpus is now 1770659 characters long
#
# Reading 'data\got2.txt'...
# Corpus is now 4071041 characters long
#
# Reading 'data\got3.txt'...
# Corpus is now 6391405 characters long
#
# Reading 'data\got4.txt'...
# Corpus is now 8107945 characters long
#
# Reading 'data\got5.txt'...
# Corpus is now 9719485 characters long

# %% [markdown]
# **Split the corpus into sentences**

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# Heraldic crest by Virginia Norey.
# ['Heraldic', 'crest', 'by', 'Virginia', 'Norey']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 1,818,103 tokens

# %% [markdown]
# ## Train Word2Vec

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 200
#num_features = 300
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 5
#context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(sentences)
# Out:
# 2019-10-22 00:17:12,012 : INFO : collecting all words and their counts
# 2019-10-22 00:17:12,013 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-10-22 00:17:12,038 : INFO : PROGRESS: at sentence #10000, processed 140984 words, keeping 10280 word types
# 2019-10-22 00:17:12,062 : INFO : PROGRESS: at sentence #20000, processed 279730 words, keeping 13558 word types
# 2019-10-22 00:17:12,085 : INFO : PROGRESS: at sentence #30000, processed 420336 words, keeping 16598 word types
# 2019-10-22 00:17:12,111 : INFO : PROGRESS: at sentence #40000, processed 556581 words, keeping 18324 word types
# 2019-10-22 00:17:12,133 : INFO : PROGRESS: at sentence #50000, processed 686247 words, keeping 19714 word types
# 2019-10-22 00:17:12,161 : INFO : PROGRESS: at sentence #60000, processed 828497 words, keeping 21672 word types
# 2019-10-22 00:17:12,188 : INFO : PROGRESS: at sentence #70000, processed 973830 words, keeping 23093 word types
# 2019-10-22 00:17:12,218 : INFO : PROGRESS: at sentence #80000, processed 1114967 words, keeping 24252 word types
# 2019-10-22 00:17:12,245 : INFO : PROGRESS: at sentence #90000, processed 1260481 words, keeping 26007 word types
# 2019-10-22 00:17:12,268 : INFO : PROGRESS: at sentence #100000, processed 1393203 words, keeping 26884 word types
# 2019-10-22 00:17:12,293 : INFO : PROGRESS: at sentence #110000, processed 1532150 words, keeping 27809 word types
# 2019-10-22 00:17:12,318 : INFO : PROGRESS: at sentence #120000, processed 1680961 words, keeping 28486 word types
# 2019-10-22 00:17:12,343 : INFO : collected 29026 word types from a corpus of 1818103 raw words and 128868 sentences
# 2019-10-22 00:17:12,343 : INFO : Loading a fresh vocabulary
# 2019-10-22 00:17:12,369 : INFO : effective_min_count=3 retains 17277 unique words (59% of original 29026, drops 11749)
# 2019-10-22 00:17:12,369 : INFO : effective_min_count=3 leaves 1802699 word corpus (99% of original 1818103, drops 15404)
# 2019-10-22 00:17:12,406 : INFO : deleting the raw counts dictionary of 29026 items
# 2019-10-22 00:17:12,406 : INFO : sample=0.001 downsamples 50 most-common words
# 2019-10-22 00:17:12,408 : INFO : downsampling leaves estimated 1404424 word corpus (77.9% of prior 1802699)
# 2019-10-22 00:17:12,441 : INFO : estimated required memory for 17277 words and 200 dimensions: 36281700 bytes
# 2019-10-22 00:17:12,441 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
#print("Word2Vec vocabulary length:", len(thrones2vec.vocab))
# Out:
# Word2Vec vocabulary length: 17277
# Word2Vec vocabulary length: 17277

# %% [markdown]
# **Start training, this might take a minute or two...**

# %%
thrones2vec.train(sentences, total_words=thrones2vec.corpus_total_words, epochs=11)
#thrones2vec.train(sentences)
# Out:
# 2019-10-22 00:17:12,646 : INFO : training model with 12 workers on 17277 vocabulary and 200 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2019-10-22 00:17:13,662 : INFO : EPOCH 1 - PROGRESS: at 58.76% words, 822918 words/s, in_qsize 23, out_qsize 0
# 2019-10-22 00:17:14,191 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:14,196 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:14,202 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:14,204 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:14,228 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:14,237 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:14,250 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:14,251 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:14,254 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:14,260 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:14,264 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:14,270 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:14,270 : INFO : EPOCH - 1 : training on 1818103 raw words (1404990 effective words) took 1.6s, 871284 effective words/s
# 2019-10-22 00:17:15,291 : INFO : EPOCH 2 - PROGRESS: at 60.41% words, 844777 words/s, in_qsize 23, out_qsize 0
# 2019-10-22 00:17:15,801 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:15,809 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:15,812 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:15,821 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:15,832 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:15,834 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:15,845 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:15,848 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:15,864 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:15,869 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:15,875 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:15,876 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:15,877 : INFO : EPOCH - 2 : training on 1818103 raw words (1405211 effective words) took 1.6s, 882409 effective words/s
# 2019-10-22 00:17:16,891 : INFO : EPOCH 3 - PROGRESS: at 60.41% words, 847860 words/s, in_qsize 24, out_qsize 1
# 2019-10-22 00:17:17,398 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:17,399 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:17,405 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:17,431 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:17,432 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:17,435 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:17,437 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:17,442 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:17,451 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:17,452 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:17,460 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:17,461 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:17,461 : INFO : EPOCH - 3 : training on 1818103 raw words (1403821 effective words) took 1.6s, 892733 effective words/s
# 2019-10-22 00:17:18,476 : INFO : EPOCH 4 - PROGRESS: at 62.61% words, 879548 words/s, in_qsize 23, out_qsize 0
# 2019-10-22 00:17:18,945 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:18,952 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:18,953 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:18,963 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:18,970 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:18,973 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:18,981 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:18,984 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:18,990 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:18,992 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:18,995 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:19,011 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:19,012 : INFO : EPOCH - 4 : training on 1818103 raw words (1403647 effective words) took 1.5s, 913444 effective words/s
# 2019-10-22 00:17:20,039 : INFO : EPOCH 5 - PROGRESS: at 57.67% words, 799494 words/s, in_qsize 23, out_qsize 0
# 2019-10-22 00:17:20,576 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:20,579 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:20,607 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:20,608 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:20,611 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:20,617 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:20,618 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:20,627 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:20,632 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:20,635 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:20,640 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:20,643 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:20,643 : INFO : EPOCH - 5 : training on 1818103 raw words (1404959 effective words) took 1.6s, 867530 effective words/s
# 2019-10-22 00:17:21,661 : INFO : EPOCH 6 - PROGRESS: at 62.06% words, 868542 words/s, in_qsize 23, out_qsize 0
# 2019-10-22 00:17:22,116 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:22,125 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:22,126 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:22,129 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:22,145 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:22,152 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:22,153 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:22,157 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:22,163 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:22,167 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:22,174 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:22,187 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:22,187 : INFO : EPOCH - 6 : training on 1818103 raw words (1404021 effective words) took 1.5s, 916383 effective words/s
# 2019-10-22 00:17:23,201 : INFO : EPOCH 7 - PROGRESS: at 58.21% words, 818528 words/s, in_qsize 23, out_qsize 0
# 2019-10-22 00:17:23,743 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:23,759 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:23,760 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:23,787 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:23,796 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:23,808 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:23,812 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:23,816 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:23,817 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:23,819 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:23,822 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:23,830 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:23,830 : INFO : EPOCH - 7 : training on 1818103 raw words (1404757 effective words) took 1.6s, 861433 effective words/s
# 2019-10-22 00:17:24,845 : INFO : EPOCH 8 - PROGRESS: at 63.16% words, 886945 words/s, in_qsize 23, out_qsize 0
# 2019-10-22 00:17:25,323 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:25,330 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:25,332 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:25,333 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:25,356 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:25,357 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:25,360 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:25,368 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:25,370 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:25,373 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:25,378 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:25,382 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:25,382 : INFO : EPOCH - 8 : training on 1818103 raw words (1404026 effective words) took 1.5s, 912041 effective words/s
# 2019-10-22 00:17:26,400 : INFO : EPOCH 9 - PROGRESS: at 61.51% words, 861791 words/s, in_qsize 23, out_qsize 0
# 2019-10-22 00:17:26,862 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:26,865 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:26,869 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:26,873 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:26,889 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:26,906 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:26,909 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:26,912 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:26,914 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:26,921 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:26,922 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:26,922 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:26,923 : INFO : EPOCH - 9 : training on 1818103 raw words (1404432 effective words) took 1.5s, 919385 effective words/s
# 2019-10-22 00:17:27,953 : INFO : EPOCH 10 - PROGRESS: at 63.16% words, 873104 words/s, in_qsize 23, out_qsize 0
# 2019-10-22 00:17:28,470 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:28,475 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:28,476 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:28,488 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:28,503 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:28,519 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:28,525 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:28,533 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:28,534 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:28,539 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:28,542 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:28,548 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:28,548 : INFO : EPOCH - 10 : training on 1818103 raw words (1404678 effective words) took 1.6s, 870702 effective words/s
# 2019-10-22 00:17:29,567 : INFO : EPOCH 11 - PROGRESS: at 58.76% words, 821454 words/s, in_qsize 23, out_qsize 0
# 2019-10-22 00:17:30,111 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2019-10-22 00:17:30,119 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2019-10-22 00:17:30,123 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2019-10-22 00:17:30,144 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2019-10-22 00:17:30,153 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-10-22 00:17:30,159 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-10-22 00:17:30,163 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-10-22 00:17:30,165 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-10-22 00:17:30,169 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-10-22 00:17:30,170 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-10-22 00:17:30,173 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-10-22 00:17:30,183 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-10-22 00:17:30,184 : INFO : EPOCH - 11 : training on 1818103 raw words (1403860 effective words) took 1.6s, 864885 effective words/s
# 2019-10-22 00:17:30,184 : INFO : training on a 19999133 raw words (15448402 effective words) took 17.5s, 880879 effective words/s
# (15448402, 19999133)

# %% [markdown]
# **Save to file, can be useful later**

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.save(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2019-10-22 00:17:30,203 : INFO : saving Word2Vec object under trained\thrones2vec.w2v, separately None
# 2019-10-22 00:17:30,204 : INFO : not storing attribute vectors_norm
# 2019-10-22 00:17:30,206 : INFO : not storing attribute cum_table
# 2019-10-22 00:17:30,453 : INFO : saved trained\thrones2vec.w2v

# %% [markdown]
# ## Explore the trained model.

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2019-10-22 00:17:30,458 : INFO : loading Word2Vec object from trained\thrones2vec.w2v
# 2019-10-22 00:17:30,703 : INFO : loading wv recursively from trained\thrones2vec.w2v.wv.* with mmap=None
# 2019-10-22 00:17:30,704 : INFO : setting ignored attribute vectors_norm to None
# 2019-10-22 00:17:30,704 : INFO : loading vocabulary recursively from trained\thrones2vec.w2v.vocabulary.* with mmap=None
# 2019-10-22 00:17:30,706 : INFO : loading trainables recursively from trained\thrones2vec.w2v.trainables.* with mmap=None
# 2019-10-22 00:17:30,706 : INFO : setting ignored attribute cum_table to None
# 2019-10-22 00:17:30,707 : INFO : loaded trained\thrones2vec.w2v

# %% [markdown]
# ### Compress the word vectors into 2D space and plot them

# %%
#my video - how to visualize a dataset easily
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = thrones2vec.trainables.syn1neg
#all_word_vectors_matrix = thrones2vec.syn0

# %% [markdown]
# **Train t-SNE, this could take a minute or two...**

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# **Plot the big picture**

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[thrones2vec.wv.vocab[word].index])
            for word in thrones2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#         word          x          y
# 0       This -12.439946 -16.769281
# 1    edition -44.544273  31.148560
# 2        the  11.308488  12.801117
# 3   complete -18.151379   0.622398
# 4         of   0.310869  10.664516
# 5   original  -3.982500 -10.281551
# 6  hardcover -44.137535  30.656042
# 7        ONE -47.027420  20.673573
# 8          A   9.602784   3.482767
# 9         OF -49.114838  27.926304

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %% [markdown]
# **Zoom in to some interesting places**

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %% [markdown]
# **People related to Kingsguard ended up together**

# %%
plot_region(x_bounds=(4.0, 4.2), y_bounds=(-0.5, -0.1))

# %% [markdown]
# **Food products are grouped nicely as well. Aerys (The Mad King) being close to "roasted" also looks sadly correct**

# %%
plot_region(x_bounds=(0, 1), y_bounds=(4, 4.5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-635bb73d3e2c> in <module>()
# ----> 1 plot_region(x_bounds=(0, 1), y_bounds=(4, 4.5))
#
# <ipython-input-58-e43b5d403e4d> in plot_region(x_bounds, y_bounds)
#       7     ]
#       8
# ----> 9     ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
#      10     for i, point in slice.iterrows():
#      11         ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1741         if isinstance(data, ABCDataFrame):
#    1742             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1743                              kind=kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     843             # the handling of this argument later
#     844             s = 20
# --> 845         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     846         if is_integer(c) and not self.data.columns.holds_integer():
#     847             c = self.data.columns[c]
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     818             y = self.data.columns[y]
#     819         if len(self.data[x]._get_numeric_data()) == 0:
# --> 820             raise ValueError(self._kind + ' requires x column to be numeric')
#     821         if len(self.data[y]._get_numeric_data()) == 0:
#     822             raise ValueError(self._kind + ' requires y column to be numeric')
#
# ValueError: scatter requires x column to be numeric

# %% [markdown]
# ### Explore semantic similarities between book characters

# %% [markdown]
# **Words closest to the given word**

# %%
thrones2vec.most_similar("Stark")
# Out:
# C:\Users\lucar\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 2019-10-22 00:38:56,325 : INFO : precomputing L2-norms of word weight vectors
# [('Eddard', 0.6827921867370605),
#  ('executed', 0.5495690107345581),
#  ('Karstark', 0.5340383648872375),
#  ('Robb', 0.5235292315483093),
#  ('absently', 0.513822615146637),
#  ('Winterfell', 0.5117062926292419),
#  ('Edrick', 0.5104243755340576),
#  ('beheaded', 0.5104086995124817),
#  ('Lyanna', 0.5025713443756104),
#  ('boyhood', 0.5009626150131226)]

# %%
thrones2vec.most_similar("Aerys")
# Out:
# C:\Users\lucar\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('Jaehaerys', 0.6483460664749146),
#  ('II', 0.6374136805534363),
#  ('Daeron', 0.6246479749679565),
#  ('Conciliator', 0.6022646427154541),
#  ('Beggar', 0.5994874238967896),
#  ('Maekar', 0.5899921655654907),
#  ('Mad', 0.5846443176269531),
#  ('Cruel', 0.581684947013855),
#  ('Unlikely', 0.5809341669082642),
#  ('Unworthy', 0.577689528465271)]

# %%
thrones2vec.most_similar("direwolf")
# Out:
# C:\Users\lucar\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('wolf', 0.5801998376846313),
#  ('SHAGGYDOG', 0.5285704135894775),
#  ('pup', 0.5275605916976929),
#  ('GHOST', 0.5124660730361938),
#  ('Ghost', 0.5101807117462158),
#  ('Rickon', 0.4954892098903656),
#  ('muzzle', 0.4872754216194153),
#  ('Shaggydog', 0.48648977279663086),
#  ('RICKON', 0.48236823081970215),
#  ('Stark', 0.4787527322769165)]

# %% [markdown]
# **Linear relationships between word pairs**

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = thrones2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("Stark", "Winterfell", "Riverrun")
nearest_similarity_cosmul("Jaime", "sword", "wine")
nearest_similarity_cosmul("Arya", "Nymeria", "dragons")
# Out:
# Stark is related to Winterfell, as Tully is related to Riverrun
# Jaime is related to sword, as hippocras is related to wine
# Arya is related to Nymeria, as Brienne is related to dragons
# C:\Users\lucar\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `most_similar_cosmul` (Method will be removed in 4.0.0, use self.wv.most_similar_cosmul() instead).
#   after removing the cwd from sys.path.
# 'Brienne'

# %% [markdown]
# # Aufgaben Testat Word2Vec

# %% [markdown]
# ### Wie ähnlich sind sich Jon und Ygritte?

# %%
thrones2vec.wv.similarity("Jon","Ygritte")
# Out:
# 0.55232704

# %% [markdown]
# ### Wie sieht der Vektor aus zu Arryn?

# %%
thrones2vec.wv.get_vector("Arryn")
# Out:
# array([ 0.18561   ,  0.35875365,  0.2601436 , -0.13405934,  0.3683659 ,
#        -0.43380624, -0.11412003,  0.22432289, -0.4464936 ,  0.28248286,
#        -0.02522176,  0.16014314,  0.5067796 ,  0.06479654, -0.1785122 ,
#         0.36805403, -0.11137998, -0.19977604,  0.03389481, -0.14497769,
#         0.13316497,  0.17746145, -0.22390784,  0.24420539, -0.10045806,
#         0.37383208,  0.21293247, -0.2590802 , -0.18462643, -0.10966399,
#        -0.02974858,  0.12958747,  0.05709292, -0.07694476, -0.24200153,
#         0.02696481,  0.38937417, -0.14927085,  0.26068386, -0.23044251,
#         0.46072724,  0.16512434, -0.7006726 , -0.32973582, -0.13905676,
#         0.42038187,  0.13829844,  0.06291134,  0.33847344, -0.03027559,
#         0.01250862, -0.04532741, -0.0675396 ,  0.32865462,  0.49936154,
#        -0.06102641,  0.541448  ,  0.24408393,  0.21614273,  0.13983195,
#         0.07643694,  0.3672763 ,  0.9518436 ,  0.47976232,  0.63618845,
#        -0.16757454,  0.11722561,  0.25673392,  0.17206694,  0.34487084,
#        -0.21115834,  0.6747864 , -0.29389846, -0.1498199 , -0.12750073,
#        -0.14136617, -0.25778863, -0.11635391,  0.35199472,  0.3401348 ,
#        -0.60016024,  0.31507015, -0.30192792,  0.0055873 ,  0.15565453,
#        -0.19762515,  0.0030738 ,  0.26653346, -0.33381942,  0.04171277,
#        -0.01831483, -0.48950443,  0.31839108, -0.3209333 ,  0.4335759 ,
#        -0.09437747,  0.21777543, -0.06753979, -0.1861379 , -0.19557798,
#         0.00454241,  0.15099692,  0.08315483, -0.18139666,  0.08381166,
#        -0.27689505,  0.26542   , -0.73167664,  0.15735239,  0.04303157,
#         0.2402236 ,  0.2834948 , -0.23534955, -0.23653167, -0.05978119,
#         0.22868285, -0.0621637 ,  0.20914868, -0.5700162 ,  0.23554915,
#         0.50284797,  0.2987163 ,  0.14456093, -0.17764041,  0.0571546 ,
#         0.15398441, -0.49059695, -0.20022032,  0.19938774,  0.31449547,
#        -0.01335416, -0.25745678, -0.38645852, -0.3554084 , -0.08264957,
#         0.62741405,  0.1664826 ,  0.01176248, -0.06706213, -0.05772088,
#        -0.8404482 , -0.46055603, -0.1488421 , -0.10236087, -0.25650105,
#         0.19893035, -0.3933299 ,  0.2764682 , -0.01580692,  0.03301997,
#         0.29486585,  0.6275554 ,  0.41343006,  0.01241894, -0.32241628,
#         0.02080835,  0.35977212, -0.34934887,  0.2624307 , -0.01670523,
#         0.07422491,  0.20814173,  0.2038177 , -0.308591  , -0.14602643,
#        -0.6262695 ,  0.1176132 ,  0.5412928 ,  0.4482498 , -0.14397705,
#         0.07793185, -0.08992312,  0.13760842,  0.23302191, -0.626535  ,
#        -0.34675065,  0.07317962,  0.15710203,  0.3623535 , -0.33993685,
#        -0.42581946,  0.0549736 ,  0.35915345,  0.5259157 , -0.2392824 ,
#        -0.51721066, -0.02422857,  0.50700086,  0.24881907,  0.03083701,
#        -0.41340813, -0.08235516,  0.07517749,  0.36735833, -0.26823428,
#         0.21073836, -0.1914031 ,  0.13540837, -0.15298416, -0.08187454],
#       dtype=float32)

# %% [markdown]
# ### Welche 7 Wörter sind am ähnlichsten zu Lannister?

# %%
thrones2vec.wv.("Lannister", topn=7)
# Out:
#   File "<ipython-input-1-d63fbd9fde33>", line 1
#     thrones2vec.wv.
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Was ergibt: Stark + Winterfell – Dragons?

# %%
thrones2vec.wv.most_similar(positive=['Stark', 'Winterfell'], negative=['Dragons'], topn=1)
# Out:
# [('Eddard', 0.5765367746353149)]

# %% [markdown]
# ### Was passt nicht „Winterfell, Riverrun, Jaime“?

# %%
thrones2vec.wv.doesnt_match('Winterfell Riverrun Jaime'.split())
# Out:
# 'Jaime'

# %% [markdown]
# ### Wie ähnlich sind sich folgende Sätze?
#
# Satz1: „Hodor That was all he ever said“ /
# Satz2: „Hold the door“

# %%
satz1 = 'Hodor That was all he ever said'.lower().split()
satz2 = 'Hold the door'.lower().split()
similarity = thrones2vec.wv.wmdistance(satz1, satz2)
print(similarity)
# Out:
# 2019-10-22 01:02:04,164 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-10-22 01:02:04,165 : INFO : built Dictionary(10 unique tokens: ['all', 'ever', 'he', 'hodor', 'said']...) from 2 documents (total 10 corpus positions)
# 4.200335540997195
